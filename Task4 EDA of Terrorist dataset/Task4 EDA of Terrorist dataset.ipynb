# %% [markdown]
# # TASK 4 : Exploratory Data Analysis - Terrorism

# %% [markdown]
# # Objective

# %% [markdown]
# Analysize the dataset and get find important fact and hot zone from the dataset

# %% [markdown]
# # Dataset

# %% [markdown]
# Click here to download the dataset : https://bit.ly/2TK5Xn5

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %% [markdown]
# ## Read the dataset

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv",encoding = "ISO-8859-1")
# Out:
# C:\Users\tauseefnawaz\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ## Plot heatmap to see missing values from dataset

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# # Handling Missing Values in dataset

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)        
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        return mis_val_table_ren_columns

# %%
pd.set_option("max_rows", None)

#get the each feature with percentage of missing values from dataset
missing_value_df = missing_values_table(df)
missing_value_df
# Out:
# Your selected dataframe has 135 columns.
# There are 106 columns that have missing values.
#                     Missing Values  % of Total Values
# gsubname3                   181671              100.0
# weapsubtype4                181621              100.0
# weapsubtype4_txt            181621              100.0
# weaptype4                   181618              100.0
# weaptype4_txt               181618              100.0
# claimmode3                  181558               99.9
# claimmode3_txt              181558               99.9
# gsubname2                   181531               99.9
# claim3                      181373               99.8
# guncertain3                 181371               99.8
# gname3                      181367               99.8
# divert                      181367               99.8
# attacktype3                 181263               99.8
# attacktype3_txt             181263               99.8
# ransomnote                  181177               99.7
# ...

# %%
#drop the features which has more than 50% missing values
delete_columns = missing_value_df[missing_value_df.iloc[:,1]>50].index

df_cleaned_missingvalue_column = df.drop(delete_columns,axis=1)

# %%
pd.set_option("max_columns", None)
df_cleaned_missingvalue_column.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate           city   latitude  \
# 0       2  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1       1                North America   Federal    Mexico city  19.371887
# 2       5               Southeast Asia    Tarlac        Unknown  15.478598
# 3       8               Western Europe    Attica         Athens  37.997490
# 4       4                    East Asia   Fukouka        Fukouka  33.580412
#
# ...

# %%
#Renaming the columns
df_cleaned_missingvalue_column.rename(columns={'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country',
                   'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','weapdetail':'Weapon_detail','motive':'Motive','city':'City'
                               ,'latitude':'Latitude','longitude':'Longitude','natlty1_txt':'nationality'},inplace=True)
df_cleaned_missingvalue_column.head()
# Out:
#         eventid  Year  Month  Day  Extended  country             Country  \
# 0  197000000001  1970      7    2         0       58  Dominican Republic
# 1  197000000002  1970      0    0         0      130              Mexico
# 2  197001000001  1970      1    0         0      160         Philippines
# 3  197001000002  1970      1    0         0       78              Greece
# 4  197001000003  1970      1    0         0      101               Japan
#
#    region                       Region    State           City   Latitude  \
# 0       2  Central America & Caribbean      NaN  Santo Domingo  18.456792
# 1       1                North America  Federal    Mexico city  19.371887
# 2       5               Southeast Asia   Tarlac        Unknown  15.478598
# 3       8               Western Europe   Attica         Athens  37.997490
# 4       4                    East Asia  Fukouka        Fukouka  33.580412
#
#     Longitude  specificity  vicinity Summary  crit1  crit2  crit3  doubtterr  \
# ...

# %%
df_cleaned_missingvalue_column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 58 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   Year              181691 non-null  int64
#  2   Month             181691 non-null  int64
#  3   Day               181691 non-null  int64
#  4   Extended          181691 non-null  int64
#  5   country           181691 non-null  int64
#  6   Country           181691 non-null  object
#  7   region            181691 non-null  int64
#  8   Region            181691 non-null  object
#  9   State             181270 non-null  object
#  10  City              181257 non-null  object
#  11  Latitude          177135 non-null  float64
#  12  Longitude         177134 non-null  float64
#  13  specificity       181685 non-null  float64
#  14  vicinity          181691 non-null  int64
#  15  Summary           115562 non-null  object
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df_cleaned_missingvalue_column.isnull(), cbar=False)

# %%
dup=df_cleaned_missingvalue_column[df_cleaned_missingvalue_column.duplicated()]
dup.shape
# Out:
# (0, 58)

# %% [markdown]
# # Insights from dataset

# %%
print('The region of',df_cleaned_missingvalue_column['Region'].value_counts(dropna=True, normalize=False, ascending=False).
      index[0] , 'had the highest amount of Terrorist Attacks totalled at',df_cleaned_missingvalue_column['Region'].value_counts(dropna=True, normalize=False, ascending=False).max())
print()
print('The most known city that had terror attacks was' ,df_cleaned_missingvalue_column['City'].value_counts(dropna=True, 
            normalize=False, ascending=False).index[1])
print()
print('The most known country with terror attacks was' ,df_cleaned_missingvalue_column['Country'].value_counts(dropna=True, normalize=False, ascending=False).index[0],'totalled at',
      df_cleaned_missingvalue_column['Country'].value_counts(dropna=True, normalize=False, ascending=False).max())
print()
print('The most preferred method of attack was',df_cleaned_missingvalue_column['AttackType'].value_counts(dropna=True, normalize=False, ascending=False).index[0],'totalling at',
      df_cleaned_missingvalue_column['AttackType'].value_counts(dropna=True, normalize=False, ascending=False).max())
print()
t = df_cleaned_missingvalue_column['Target_type'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
print('The main targets of terrorists were',df_cleaned_missingvalue_column['Target_type'].value_counts(dropna=True, normalize=False, ascending=False).index[0],
      'totalling at',t[0])
print()
# Out:
# The region of Middle East & North Africa had the highest amount of Terrorist Attacks totalled at 50474
#
# The most known city that had terror attacks was Baghdad
#
# The most known country with terror attacks was Iraq totalled at 24636
#
# The most preferred method of attack was Bombing/Explosion totalling at 88255
#
# The main targets of terrorists were Private Citizens & Property totalling at 23.9%

# %% [markdown]
# # Analyze the dataset by visualization graphs

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(df_cleaned_missingvalue_column["Month"])
plt.xlabel("Year")
labels = [
    "NA",
    "Jan",
    "Feb",
    "March",
    "April",
    "May",
    "June",
    "July",
    "Aug",
    "Sept",
    "Oct",
    "Nov",
    "Dec",
]
ax.set_xticklabels(labels)
plt.xticks(rotation=45)
plt.ylabel("Number of Attacks")
plt.title("No of Attacks in each month of years (1970-2017)")
plt.show();

# %%
plt.figure(figsize=(10,6))
fig = sns.distplot(df_cleaned_missingvalue_column[["Month","suicide"]].groupby("Month").aggregate(np.sum), color = 'r')
fig.set_xlabel("suicide distribution",size=15)
fig.set_ylabel("Suicide total %",size=15)
plt.title('Suicide attacks each month distribution ',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
fig = sns.countplot('Year',data=df_cleaned_missingvalue_column,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',10))
fig.set_xlabel("Year",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Number of Terror attacks each year (1970-2017)',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
fig = sns.distplot(df_cleaned_missingvalue_column[["Year","suicide"]].groupby("Year").aggregate(np.sum), color = 'r')
fig.set_xlabel("suicide distribution",size=15)
fig.set_ylabel("Suicide total %",size=15)
plt.title('Suicide attacks each year distribution ',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
region_attacks = df_cleaned_missingvalue_column["Region"].value_counts()
fig = sns.barplot(x=region_attacks,y=region_attacks.index)
fig.set_xlabel("Region",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Number of Total Attacks in Each Region',size = 20)
plt.show()

# %%
plt.rcParams['figure.figsize']=18,7
terror_area=pd.crosstab(df_cleaned_missingvalue_column.Year,df_cleaned_missingvalue_column.Region)
terror_area.plot()
plt.title('Trend of terror attacks in each region')
plt.show()

# %%
plt.figure(figsize=(10,6))
country_attacks =  df_cleaned_missingvalue_column['Country'].value_counts()[:15]
fig = sns.barplot(x=country_attacks.index,y=country_attacks)
fig.set_xlabel("Country",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=30)
plt.title('Total Number of Total Attacks in Each Country',size = 20)
for p in fig.patches:
     fig.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
         ha='center', va='center', fontsize=10, color='gray', xytext=(0, 20),
         textcoords='offset points')
plt.show()

# %%
plt.rcParams['figure.figsize']=18,7
terror_area=pd.crosstab(df_cleaned_missingvalue_column.Year,df_cleaned_missingvalue_column[df_cleaned_missingvalue_column.Country.isin(list(country_attacks.index))].Country)
terror_area.plot()
plt.title('Trend of terror attacks in each Country')
plt.show()

# %%
plt.figure(figsize=(10,6))
city_attacks = df_cleaned_missingvalue_column[df_cleaned_missingvalue_column['City']!="Unknown"]['City'].value_counts()[:15]
fig = sns.barplot(x=city_attacks,y=city_attacks.index)
fig.set_xlabel("Region",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Number of Total Attacks in Each City',size = 20)

plt.show()

# %%
plt.rcParams['figure.figsize']=18,7
terror_area=pd.crosstab(df_cleaned_missingvalue_column.Year,df_cleaned_missingvalue_column[df_cleaned_missingvalue_column.City.isin(list(city_attacks.index))].City)
terror_area.plot()
plt.title('Trend of terror attacks in each city')
plt.show()

# %%
plt.figure(figsize=(10,6))
nationality = df_cleaned_missingvalue_column["nationality"].value_counts()[:15]
fig = sns.barplot(x=nationality,y=nationality.index)
fig.set_xlabel("nationality",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Each nationality suffer from total Number of Total Attacks',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
city_attacks = df_cleaned_missingvalue_column['Target_type'].value_counts()
fig = sns.barplot(x=city_attacks,y=city_attacks.index)
fig.set_xlabel("Region",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Number of Total Attacks for Each Target type',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
nationality = df_cleaned_missingvalue_column[df_cleaned_missingvalue_column["Group"]!="Unknown"]["Group"].value_counts()[:15]
fig = sns.barplot(x=nationality,y=nationality.index)
fig.set_xlabel("nationality",size=15)
fig.set_ylabel("Terror attack total",size=15)
plt.xticks(rotation=90)
plt.title('Number of Total Attacks did by each Militant Group',size = 20)
plt.show()

# %%
plt.figure(figsize=(10,6))
weapons = df_cleaned_missingvalue_column[df_cleaned_missingvalue_column['Weapon_type']!="Unknown"]['Weapon_type'].value_counts()
weapons.index = ['Explosives', 'Firearms', 'Incendiary', 'Melee', 'Chemical',
       'Sabotage Equipment','Vehicle','Other', 'Biological', 'Fake Weapons', 'Radiological']
fig = sns.barplot(x=weapons.index,y=weapons)
fig.set_xlabel("Weapons",size=15)
fig.set_ylabel(" Terror attack total",size=15)
plt.xticks(rotation=30)
plt.title('Number of Weapon Used for attacks',size = 20)
for p in fig.patches:
     fig.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
         ha='center', va='center', fontsize=11, color='gray', xytext=(0, 20),
         textcoords='offset points')
plt.show()

# %%
plt.rcParams['figure.figsize']=(14,9)
label1=df_cleaned_missingvalue_column['AttackType'].value_counts()[:5].index
size=df_cleaned_missingvalue_column['AttackType'].value_counts()[:5].values
explode = (0.1, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(size, explode=explode, labels=label1, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage for Each Attack type',size = 20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(14,9)
explode = (0, 0.1)
labels=['controlled with in 24 hours','extended more than 24 hours']
plt.pie(df['extended'].value_counts(), explode=explode, autopct='%1.1f%%')
plt.title('percentage of attacks extended more than 24 hours',size = 20)
plt.legend(labels, fontsize=10)
plt.show()

# %% [markdown]
# # Other key findings:

# %% [markdown]
# 2014 saw the most number of terrorist attacks (Total=16903), closely followed by 2015 (Total=14965) and 2016 (13587).
#
# Iraq is the most attacked country in the world.
#
# Baghdad is the unsafest city in the world, witnessing 7589 attacks.
#
# 21151 people have been killed in Baghdad, and 78589 people in Iraq.
#
# Bombing/Explosion is most frequent methods of attacks.
#
# Explosives and firearms are mostly used weapons in attacks.
#
# Till 2017, 24113 Iraqi nationals have been killed in terrorist attacks.
#
# Taliban was involved in most of the terrorist attacks.
